# %%
import csv
import re
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dates = []
prices = []

with open("BTC_data.csv") as csvfile:
    reader = list(csv.reader(csvfile))[1::]
    for i in range(len(reader)):
        date = reader[i][0]
        datenew = re.sub(r"[^\w]", "", date)
        dates.append(int(datenew))
        prices.append(float(reader[i][1]))

#priceslog = [log10(x) for x in prices]
prices_log = []
for i in range(len(prices)):
    price = prices[i]
    #price = inst[0]
    if price == 0:
        prices_log.append(1)
    else:
        log_price = log10(price)
        prices_log.append(log_price)

#for i in range(len(data3)):
#    inst = data3[i]
#    plt.scatter(i, inst[0], marker='o', color='red')
dates_log = dates[::-1] 
prices_log = prices_log[::-1]
##prices_log = [log10(x) for x in prices]
#print(type(dates_log))

print(len(dates_log))
print(len(dates))
print(prices_log[0])
# Out:
# 2276
# 2276
# 0.763427993563

# %%
#split to test data and train data

train_dates0 = dates_log[:1800]
train_prices0 = prices_log[:1800] 
test_dates0 = dates_log[1800:]
test_prices0 = prices_log[1800:]

# %%
dates_mat = np.reshape(dates_log,(len(dates_log),1)) # converting to matrix of n X 1
prices_mat = np.reshape(prices_log,(len(prices_log),1))
plt.scatter(dates_mat, prices_mat, color= 'black', label= 'Data') # plotting the initial datapoints 
plt.show()

# %%
# Reshape train and test data

train_dates = np.reshape(train_dates0,(len(train_dates0),1)) # converting to matrix of n X 1
train_prices = np.reshape(train_prices0,(len(train_prices0),1))
test_dates = np.reshape(test_dates0,(len(test_dates0),1)) 
test_prices = np.reshape(test_prices0,(len(test_prices0),1))

# %%
# Linear regression !
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

LR = LinearRegression()
LR.fit(dates_mat, prices_mat) 

plt.scatter(dates_mat, prices_mat, color= 'black', label= 'Data') # plotting the initial datapoints 
plt.plot(dates_mat, LR.predict(dates_mat), color= 'red', label= 'Linear model') # plotting the line made by linear regression
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
# Linear regression test on TEST SET


LR2 = LinearRegression()
LR2.fit(train_dates, train_prices) 

plt.scatter(dates_mat, prices_mat, color= 'black', label= 'Data') # plotting the initial datapoints 
plt.plot(test_dates, LR2.predict(test_dates), color= 'red', label= 'Linear model') # plotting the line made by linear regression
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
#SVM regression
from sklearn import svm
SVR = svm.SVR()
SVR.fit(dates_mat, prices_mat)

plt.scatter(dates_mat, prices_mat, color= 'black', label= 'Data') # plotting the initial datapoints 
plt.plot(dates_mat, SVR.predict(dates_mat), color= 'red', label= 'Linear model') # plotting the line made by linear regression
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %%
# SVM test on TEST SET

SVR2 = svm.SVR()
SVR2.fit(train_dates, train_prices)

plt.scatter(dates_mat, prices_mat, color= 'black', label= 'Data') # plotting the initial datapoints 
plt.plot(test_dates, SVR2.predict(test_dates), color= 'red', label= 'Linear model') # plotting the line made by linear regression
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %%
#Random forest Regressor
from sklearn.ensemble import RandomForestRegressor

RFR = RandomForestRegressor()
RFR.fit(dates_mat, prices_mat)

plt.scatter(dates_mat, prices_mat, color= 'black', label= 'Data') # plotting the initial datapoints 
plt.plot(dates_mat, RFR.predict(dates_mat), color= 'red', label= 'Linear model') # plotting the line made by linear regression
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('SVM Regression')
plt.legend()
plt.show()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """

# %%
#Random forest Regressor test on TEST SET

RFR2 = RandomForestRegressor()
RFR2.fit(train_dates, train_prices)

plt.scatter(dates_mat, prices_mat, color= 'black', label= 'Data') # plotting the initial datapoints 
plt.plot(test_dates, RFR2.predict(test_dates), color= 'red', label= 'Linear model') # plotting the line made by linear regression
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('SVM Regression')
plt.legend()
plt.show()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
